# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_excel("data-train.xlsx")

# %%
data.head
# Out:
# <bound method NDFrame.head of      slength  sepalwidth  petallength  petalwidth           class
# 0        5.1         3.5          1.4         0.2     Iris-setosa
# 1        4.9         3.0          1.4         0.2     Iris-setosa
# 2        4.7         3.2          1.3         0.2     Iris-setosa
# 3        4.6         3.1          1.5         0.2     Iris-setosa
# 4        5.0         3.6          1.4         0.2     Iris-setosa
# ..       ...         ...          ...         ...             ...
# 137      6.7         3.0          5.2         2.3  Iris-virginica
# 138      6.3         2.5          5.0         1.9  Iris-virginica
# 139      6.5         3.0          5.2         2.0  Iris-virginica
# 140      6.2         3.4          5.4         2.3  Iris-virginica
# 141      5.9         3.0          5.1         1.8  Iris-virginica
#
# [142 rows x 5 columns]>

# %%
x = data.iloc[:,:-1]

# %%
x
# Out:
#      slength  sepalwidth  petallength  petalwidth
# 0        5.1         3.5          1.4         0.2
# 1        4.9         3.0          1.4         0.2
# 2        4.7         3.2          1.3         0.2
# 3        4.6         3.1          1.5         0.2
# 4        5.0         3.6          1.4         0.2
# ..       ...         ...          ...         ...
# 137      6.7         3.0          5.2         2.3
# 138      6.3         2.5          5.0         1.9
# 139      6.5         3.0          5.2         2.0
# 140      6.2         3.4          5.4         2.3
# 141      5.9         3.0          5.1         1.8
#
# [142 rows x 4 columns]

# %%
y = data.iloc[:,-1]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# Name: class, Length: 142, dtype: object

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x.values,y.values)
# Out:
# DecisionTreeClassifier()

# %% [raw]
# predictions = model.predict([[4.9, 3.1, 1.5, 0.1]])

# %%
data_test = pd.read_excel("data-test.xlsx")

# %%
x_test = data_test.iloc[:,:-1]

# %%
y_test = data_test.iloc[:,-1]

# %%
predictions = model.predict(x_test.values)

# %%
predictions
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa'],
#       dtype=object)

# %%
actual = y_test.values

# %%
actual
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa'],
#       dtype=object)

# %%
count = 0
for i in range (0,len(actual)):
    if actual[i] == predictions[i]:
        count = count + 1
print("The ML model accuracy trained on iris dataset is : ")
print(count * 100 /len(actual))
# Out:
# The ML model accuracy trained on iris dataset is :
# 100.0
